# %%
import pandas as pd

# %%
dfs = pd.read_html("https://fr.piliapp.com/emoji/list/travel-places/")
df = dfs[0]
print(df)
# Out:
#     Emoji Texte brut      Signification Copier / Coller Unnamed: 4 Unnamed: 5
# 0     NaN          🚗         Automobile          Copier        NaN        NaN
# 1     NaN          🚙        Camping-car          Copier        NaN        NaN
# 2     NaN          🚕               Taxi          Copier        NaN        NaN
# 3     NaN          🛺  Rickshaw motorisé          Copier        NaN        NaN
# 4     NaN          🚌                Bus          Copier        NaN        NaN
# ..    ...        ...                ...             ...        ...        ...
# 125   NaN          🕌            Mosquée          Copier        NaN        NaN
# 126   NaN          🛕      Temple hindou          Copier        NaN        NaN
# 127   NaN          🕍          synagogue          Copier        NaN        NaN
# 128   NaN          🕋              Kaaba          Copier        NaN        NaN
# 129   NaN          ⛩  Sanctuaire shinto          Copier        NaN        NaN
#
# [130 rows x 6 columns]

# %%
pip install scrapy
# Out:
# ...
#      |████████████████████████████████| 254 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 41.1 MB/s
# ...
#      |████████████████████████████████| 55 kB 3.2 MB/s
# ...
#      |████████████████████████████████| 251 kB 58.2 MB/s
# ...
#      |████████████████████████████████| 3.5 MB 11.8 MB/s
# ...
#      |████████████████████████████████| 3.2 MB 44.3 MB/s
# ...
#      |████████████████████████████████| 47 kB 4.3 MB/s
# ...
#      |████████████████████████████████| 74 kB 3.1 MB/s
# ...
#   Created wheel for protego: filename=Protego-0.1.16-py3-none-any.whl size=7782 sha256=56fd9adaac4ce5af03bf52b61cee29c80b74a440c42af868df02c0bed2d427fa
#   Stored in directory: /root/.cache/pip/wheels/ca/44/01/3592ccfbcfaee4ab297c4097e6e9dbe1c7697e3531a39877ab
# ...
#   Created wheel for PyDispatcher: filename=PyDispatcher-2.0.5-py3-none-any.whl size=11515 sha256=2511a1b8f6aede8c70cc15ca2c4b81639930350e23f3f7d612199679367c8ab3
# ...

# %%
dftravel1=df[["Texte brut","sens"]]

# %%
dfssmile = pd.read_html("https://fr.piliapp.com/emoji/list/smileys-people/")
dfsmile = dfssmile[0]

dfsmile1=dfsmile[["Plain text	","Meaning"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-3305c76caa15> in <module>()
#       2 dfsmile = dfssmile[0]
#       3
# ----> 4 dfsmile1=dfsmile[["Plain text   ","Meaning"]]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2910             if is_iterator(key):
#    2911                 key = list(key)
# -> 2912             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2913
#    2914         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
# ...

# %%
dfsmile = dfssmile[0]

# %%
dfsmile = dfsmile1.iloc[1:]
dfsmile1=dfsmile[["Texte brut","sens"]]
dfsmile1
# Out:
#     Texte brut                                               sens
# 1            😁  Visage souriant à pleines dents avec des yeux ...
# 2            😂                     Visage avec des larmes de joie
# 3            😃             Visage souriant avec la bouche ouverte
# 4            😄  Visage souriant avec la bouche ouverte et des ...
# 5            🤣               Mort de rire à s'en rouler par terre
# ..         ...                                                ...
# 468          🧣                                            Écharpe
# 469          🧤                                              Gants
# 470          💍                                              Bague
# 471          🌂                                    Parapluie fermé
# 472          ☂                                          Parapluie
#
# [472 rows x 2 columns]

# %%
dfsanimal = pd.read_html("https://fr.piliapp.com/emoji/list/animals-nature/#emoji-list")
dfanimal = dfsanimal[0]
dfanimal1=dfanimal[["Texte brut","sens"]]

# %%
dfsfood = pd.read_html("https://fr.piliapp.com/emoji/list/food-drink/#emoji-list")
dffood = dfsfood[0]
dffood1=dffood[["Texte brut","sens"]]

# %%
dfsactivities = pd.read_html("https://fr.piliapp.com/emoji/list/activities/#emoji-list")
dfactivities = dfsactivities[0]
dfactivities1=dfactivities[["Texte brut","sens"]]

# %%
dfsobjects = pd.read_html("https://fr.piliapp.com/emoji/list/objects/#emoji-list")
dfobjects = dfsobjects[0]
dfobjects1=dfobjects[["Texte brut","sens"]]

# %%
dfssymbols = pd.read_html("https://fr.piliapp.com/emoji/list/symbols/#emoji-list")
dfsymbols = dfssymbols[0]
dfsymbols1=dfsymbols[["Texte brut","sens"]]

# %%
dfsflags = pd.read_html("https://fr.piliapp.com/emoji/list/flags/#emoji-list")
dfflags = dfsflags[0]
dfflags1=dfflags[["Texte brut","sens"]]

# %%
framess=[dfsmile1, dftravel1, dfanimal1, dffood1, dfactivities1, dfsymbols1, dfflags1]

# %%
frames = pd.concat(framess, sort=False)

# %%
frameslist = frames.values.tolist()

# %%
le=[]
ls=[]
for i in range(len(frameslist)):
  le.append(frameslist[i][0])
  ls.append(frameslist[i][1])
print(le)
print(ls)
# Out:
# ['😁', '😂', '😃', '😄', '🤣', '😅', '😆', '😇', '😉', '😊', '🙂', '🙃', '☺', '😋', '😌', '😍', '🥰', '😘', '😗', '😙', '😚', '🤪', '😜', '😝', '😛', '🤑', '😎', '🤓', '🧐', "googletag.cmd.push(function(){ googletag.display('dfp-1'); });", '\U0001f978', '🤠', '🥳', '🤗', '🤡', '😏', '😶', '😐', '😑', '😒', '🙄', '🤨', '🤔', '🤫', '🤭', '🤥', '😳', '😞', '😟', '😠', '😡', '🤬', '😔', '😕', '🙁', '☹', '😬', '🥺', '😣', '😖', "googletag.cmd.push(function(){ googletag.display('dfp-2'); });", '😫', '😩', '\U0001f971', '😤', '😮', '😱', '😨', '😰', '😯', '😦', '😧', '😮\u200d💨', '😵\u200d💫', '😶\u200d🌫️', '😢', '😥', '😪', '\U0001f972', '🤤', '😓', '😭', '🤩', '😵', '🥴', '😲', '🤯', '🤐', '😷', '🤕', '🤒', "googletag.cmd.push(function(){ googletag.display('dfp-3'); });", '🤮', '🤢', '🤧', '🥵', '🥶', '😴', '💤', '😈', '👿', '👹', '👺', '💩', '👻', '💀', '☠', '👽', '🤖', '🎃', '😺', '😸', '😹', '😻', '😼', '😽', '🙀', '😿', '😾', '👐', '🤲', '🙌', "googletag.cmd.push(function(){ googletag.display('dfp-4'); });", '👏', '🙏', '🤝', '👍', '👎', '👊', '✊', '🤛', '🤜', '🤞', '✌', '🤘', '🤟', '👌', '\U0001f90f', '👈', 
# ...

# %%
emojidic = dict(zip(le, ls))

# %%
dictemoji=dict()
dictemoji={'📚':'books','📦':'package','📱':'mobile phone','😀':'Grinning Face','💌':'Love Letter','🎁':'Birthday Present','🖼️':'Framed Picture','★':'Black Star','📸':'Camera with Flash','🛒':'Shopping Cart' ,'☆':'star','·':'point','･':'point','📝':'Memo','📏':'Straight Ruler','🎊':'Confetti Ball','📖':'Open Book','🎉':'Party Popper','✂️':'Scissors','📄':'Page Facing Up','🖍️':'Crayon','🖇️':'Linked Paperclips','🛍️':'Shopping Bags','🔬‍':'Microscope','⚗️':'Alembic','🎥':'Movie Camera','✒️':'Black Nib','📨':'Incoming Envelope','⚔️':'Crossed Swords','📅':'Calendar','🔑':'key','⌚':'Watch','🖥️':'Desktop Computer','🎈':'Balloon','🎀':'Ribbon','🔍':'Magnifying Glass Tilted Left','⚗️':'Alembic','💡':'Light Bulb','📗':'green book','⌨️':'Keyboard','💰':'Money Bag','🗺️':'World Map','🛏️':'bed','💎':'diamant','📹':'Video Camera','🔮':'Crystal Ball','🔒':' Locked','🕯️':'Candle','🔨':'Hammer','🔭':'Telescope','🛋️':'Couch and Lamp','📰':'Newspaper','💊':'pill','🩺':'Stethoscope','🔌':'Electric Plug','🧵':'Thread','🧶':'yarn','⏰':'Alarm Clock','🧭':'Compass','🖱️':'Computer Mouse','🎙️':'Studio Microphone','💿':'Optical Disk','🖨️':'Printer','⏳':'Hourglass Not Done','🧹':'Broom','⛱':'umbrella','🛋':'couch','⛱️':'Umbrella on Ground','🧼':'soap','🗿':'Moai','📍':'Round Pushpin','🚪':'door','🧺':'Basket','📫':'Closed Mailbox with Raised Flag','🧽':'Sponge'}
emojidic.update(dictemoji)

# %%
print(emojidic)
# Out:
# {'😁': 'Visage souriant à pleines dents avec des yeux rieurs', '😂': 'Visage avec des larmes de joie', '😃': 'Visage souriant avec la bouche ouverte', '😄': 'Visage souriant avec la bouche ouverte et des yeux rieurs', '🤣': "Mort de rire à s'en rouler par terre", '😅': 'Visage souriant avec la bouche ouverte et des sueurs froides', '😆': 'Visage souriant avec la bouche ouverte et les yeux bien fermés', '😇': 'Visage souriant avec un halo', '😉': "Visage faisant un clin d'œil", '😊': 'Visage souriant avec des yeux rieurs', '🙂': 'Visage légèrement souriant', '🙃': 'Visage tête bèche', '☺': 'Visage souriant blanc', '😋': 'Visage savourant un plat délicieux', '😌': 'Visage soulagé', '😍': 'Visage souriant avec des yeux en forme de cœur', '🥰': 'Visage souriant avec 3 cœurs', '😘': 'Visage envoyant un baiser', '😗': 'Visage faisant un baiser', '😙': 'Visage faisant un baiser avec des yeux rieurs', '😚': 'Visage faisant un baiser avec les yeux fermés', '🤪': 'Visage loufoque', '😜': "Visage tirant la langue et
# ...

# %%
import pickle

emoji = open("emojidic.pkl", "wb")
pickle.dump(emojidic, emoji)
emoji.close()

# %%
import pickle
file= open("emojidic.pkl", "rb")
emoji = pickle.load(file)
print(emoji)
# Out:
# {'😁': 'Visage souriant à pleines dents avec des yeux rieurs', '😂': 'Visage avec des larmes de joie', '😃': 'Visage souriant avec la bouche ouverte', '😄': 'Visage souriant avec la bouche ouverte et des yeux rieurs', '🤣': "Mort de rire à s'en rouler par terre", '😅': 'Visage souriant avec la bouche ouverte et des sueurs froides', '😆': 'Visage souriant avec la bouche ouverte et les yeux bien fermés', '😇': 'Visage souriant avec un halo', '😉': "Visage faisant un clin d'œil", '😊': 'Visage souriant avec des yeux rieurs', '🙂': 'Visage légèrement souriant', '🙃': 'Visage tête bèche', '☺': 'Visage souriant blanc', '😋': 'Visage savourant un plat délicieux', '😌': 'Visage soulagé', '😍': 'Visage souriant avec des yeux en forme de cœur', '🥰': 'Visage souriant avec 3 cœurs', '😘': 'Visage envoyant un baiser', '😗': 'Visage faisant un baiser', '😙': 'Visage faisant un baiser avec des yeux rieurs', '😚': 'Visage faisant un baiser avec les yeux fermés', '🤪': 'Visage loufoque', '😜': "Visage tirant la langue et
# ...

# %%
from google.colab import files
files.download("emojidic.pkl")
